# %% [markdown]
# # Bitcoin Mining Pool Classifier - Data from BigQuery

# %%
from google.cloud import bigquery
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import matplotlib.patheffects as PathEffects
import matplotlib.pylab as pylab
import numpy as np
import pandas as pd
import itertools
from sklearn.metrics import  confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
import time
import seaborn as sns
from keras import utils, optimizers
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.losses import binary_crossentropy
# Out:
# Using TensorFlow backend.
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
client = bigquery.Client()
# Out:
# Using Kaggle's public dataset BigQuery integration.

# %% [markdown]
# ## Load data from BigQuery
#
# Note: I would be querying a subset of the data here due to Kaggle's resource constraints

# %%
miner_limit = 5000
non_miner_limit = 5000

# %%
# SQL query adapted from https://gist.github.com/allenday/16cf63fb6b3ed59b78903b2d414fe75b
sql = '''
WITH 
output_ages AS (
  SELECT
    ARRAY_TO_STRING(outputs.addresses,',') AS output_ages_address,
    MIN(block_timestamp_month) AS output_month_min,
    MAX(block_timestamp_month) AS output_month_max
  FROM `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(outputs) AS outputs
  GROUP BY output_ages_address
)
,input_ages AS (
  SELECT
    ARRAY_TO_STRING(inputs.addresses,',') AS input_ages_address,
    MIN(block_timestamp_month) AS input_month_min,
    MAX(block_timestamp_month) AS input_month_max
  FROM `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(inputs) AS inputs
  GROUP BY input_ages_address
)
,output_monthly_stats AS (
  SELECT
    ARRAY_TO_STRING(outputs.addresses,',') AS output_monthly_stats_address, 
    COUNT(DISTINCT block_timestamp_month) AS output_active_months,
    COUNT(outputs) AS total_tx_output_count,
    SUM(value) AS total_tx_output_value,
    AVG(value) AS mean_tx_output_value,
    STDDEV(value) AS stddev_tx_output_value,
    COUNT(DISTINCT(`hash`)) AS total_output_tx,
    SUM(value)/COUNT(block_timestamp_month) AS mean_monthly_output_value,
    COUNT(outputs.addresses)/COUNT(block_timestamp_month) AS mean_monthly_output_count
  FROM `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(outputs) AS outputs
  GROUP BY output_monthly_stats_address
)
,input_monthly_stats AS (
  SELECT
    ARRAY_TO_STRING(inputs.addresses,',') AS input_monthly_stats_address, 
    COUNT(DISTINCT block_timestamp_month) AS input_active_months,
    COUNT(inputs) AS total_tx_input_count,
    SUM(value) AS total_tx_input_value,
    AVG(value) AS mean_tx_input_value,
    STDDEV(value) AS stddev_tx_input_value,
    COUNT(DISTINCT(`hash`)) AS total_input_tx,
    SUM(value)/COUNT(block_timestamp_month) AS mean_monthly_input_value,
    COUNT(inputs.addresses)/COUNT(block_timestamp_month) AS mean_monthly_input_count
  FROM `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(inputs) AS inputs
  GROUP BY input_monthly_stats_address
)
,output_idle_times AS (
  SELECT
    address AS idle_time_address,
    AVG(idle_time) AS mean_output_idle_time,
    STDDEV(idle_time) AS stddev_output_idle_time
  FROM
  (
    SELECT 
      event.address,
      IF(prev_block_time IS NULL, NULL, UNIX_SECONDS(block_time) - UNIX_SECONDS(prev_block_time)) AS idle_time
    FROM (
      SELECT
        ARRAY_TO_STRING(outputs.addresses,',') AS address, 
        block_timestamp AS block_time,
        LAG(block_timestamp) OVER (PARTITION BY ARRAY_TO_STRING(outputs.addresses,',') ORDER BY block_timestamp) AS prev_block_time
      FROM `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(outputs) AS outputs
    ) AS event
    WHERE block_time != prev_block_time
  )
  GROUP BY address
)
,input_idle_times AS (
  SELECT
    address AS idle_time_address,
    AVG(idle_time) AS mean_input_idle_time,
    STDDEV(idle_time) AS stddev_input_idle_time
  FROM
  (
    SELECT 
      event.address,
      IF(prev_block_time IS NULL, NULL, UNIX_SECONDS(block_time) - UNIX_SECONDS(prev_block_time)) AS idle_time
    FROM (
      SELECT
        ARRAY_TO_STRING(inputs.addresses,',') AS address, 
        block_timestamp AS block_time,
        LAG(block_timestamp) OVER (PARTITION BY ARRAY_TO_STRING(inputs.addresses,',') ORDER BY block_timestamp) AS prev_block_time
      FROM `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(inputs) AS inputs
    ) AS event
    WHERE block_time != prev_block_time
  )
  GROUP BY address
)
--,miners AS (
--)

(SELECT
  TRUE AS is_miner,
  output_ages_address AS address,
  UNIX_SECONDS(CAST(output_ages.output_month_min AS TIMESTAMP)) AS output_month_min,
  UNIX_SECONDS(CAST(output_ages.output_month_max AS TIMESTAMP)) AS output_month_max,
  UNIX_SECONDS(CAST(input_ages.input_month_min AS TIMESTAMP)) AS input_month_min,
  UNIX_SECONDS(CAST(input_ages.input_month_max AS TIMESTAMP)) AS input_month_max,
  UNIX_SECONDS(CAST(output_ages.output_month_max AS TIMESTAMP)) - UNIX_SECONDS(CAST(output_ages.output_month_min AS TIMESTAMP)) AS output_active_time,
  UNIX_SECONDS(CAST(input_ages.input_month_max AS TIMESTAMP)) - UNIX_SECONDS(CAST(input_ages.input_month_min AS TIMESTAMP)) AS input_active_time,
  UNIX_SECONDS(CAST(output_ages.output_month_max AS TIMESTAMP)) - UNIX_SECONDS(CAST(input_ages.input_month_max AS TIMESTAMP)) AS io_max_lag,
  UNIX_SECONDS(CAST(output_ages.output_month_min AS TIMESTAMP)) - UNIX_SECONDS(CAST(input_ages.input_month_min AS TIMESTAMP)) AS io_min_lag,
  output_monthly_stats.output_active_months,
  output_monthly_stats.total_tx_output_count,
  output_monthly_stats.total_tx_output_value,
  output_monthly_stats.mean_tx_output_value,
  output_monthly_stats.stddev_tx_output_value,
  output_monthly_stats.total_output_tx,
  output_monthly_stats.mean_monthly_output_value,
  output_monthly_stats.mean_monthly_output_count,
  input_monthly_stats.input_active_months,
  input_monthly_stats.total_tx_input_count,
  input_monthly_stats.total_tx_input_value,
  input_monthly_stats.mean_tx_input_value,
  input_monthly_stats.stddev_tx_input_value,
  input_monthly_stats.total_input_tx,
  input_monthly_stats.mean_monthly_input_value,
  input_monthly_stats.mean_monthly_input_count,
  output_idle_times.mean_output_idle_time,
  output_idle_times.stddev_output_idle_time,
  input_idle_times.mean_input_idle_time,
  input_idle_times.stddev_input_idle_time
FROM
  output_ages, output_monthly_stats, output_idle_times,
  input_ages,  input_monthly_stats, input_idle_times
WHERE TRUE
  AND output_ages.output_ages_address = output_monthly_stats.output_monthly_stats_address
  AND output_ages.output_ages_address = output_idle_times.idle_time_address
  AND output_ages.output_ages_address = input_monthly_stats.input_monthly_stats_address
  AND output_ages.output_ages_address = input_ages.input_ages_address
  AND output_ages.output_ages_address = input_idle_times.idle_time_address
  AND output_ages.output_ages_address IN
(
  SELECT 
    ARRAY_TO_STRING(outputs.addresses,',') AS miner
  FROM 
  `bigquery-public-data.crypto_bitcoin.blocks` AS blocks,
  `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(outputs) AS outputs
  WHERE blocks.hash = transactions.block_hash 
    AND is_coinbase IS TRUE
    AND ( FALSE
      --
      -- miner signatures from https://en.bitcoin.it/wiki/Comparison_of_mining_pools
      --
      OR coinbase_param LIKE '%4d696e656420627920416e74506f6f6c%' --AntPool
      OR coinbase_param LIKE '%2f42434d6f6e737465722f%' --BCMonster
      --BitcoinAffiliateNetwork
      OR coinbase_param LIKE '%4269744d696e746572%' --BitMinter
      --BTC.com
      --BTCC Pool
      --BTCDig
      OR coinbase_param LIKE '%2f7374726174756d2f%' --Btcmp
      --btcZPool.com
      --BW Mining
      OR coinbase_param LIKE '%456c6967697573%' --Eligius
      --F2Pool
      --GHash.IO
      --Give Me COINS
      --Golden Nonce Pool
      OR coinbase_param LIKE '%2f627261766f2d6d696e696e672f%' --Bravo Mining
      OR coinbase_param LIKE '%4b616e6f%' --KanoPool
      --kmdPool.org
      OR coinbase_param LIKE '%2f6d6d706f6f6c%' --Merge Mining Pool
      --MergeMining
      --Multipool
      --P2Pool
      OR coinbase_param LIKE '%2f736c7573682f%' --Slush Pool
      --ZenPool.org
    )
  GROUP BY miner
  HAVING COUNT(1) >= 20 
)
LIMIT {})
UNION ALL
(SELECT
  FALSE AS is_miner,
  output_ages_address AS address,
  UNIX_SECONDS(CAST(output_ages.output_month_min AS TIMESTAMP)) AS output_month_min,
  UNIX_SECONDS(CAST(output_ages.output_month_max AS TIMESTAMP)) AS output_month_max,
  UNIX_SECONDS(CAST(input_ages.input_month_min AS TIMESTAMP)) AS input_month_min,
  UNIX_SECONDS(CAST(input_ages.input_month_max AS TIMESTAMP)) AS input_month_max,
  UNIX_SECONDS(CAST(output_ages.output_month_max AS TIMESTAMP)) - UNIX_SECONDS(CAST(output_ages.output_month_min AS TIMESTAMP)) AS output_active_time,
  UNIX_SECONDS(CAST(input_ages.input_month_max AS TIMESTAMP)) - UNIX_SECONDS(CAST(input_ages.input_month_min AS TIMESTAMP)) AS input_active_time,
  UNIX_SECONDS(CAST(output_ages.output_month_max AS TIMESTAMP)) - UNIX_SECONDS(CAST(input_ages.input_month_max AS TIMESTAMP)) AS io_max_lag,
  UNIX_SECONDS(CAST(output_ages.output_month_min AS TIMESTAMP)) - UNIX_SECONDS(CAST(input_ages.input_month_min AS TIMESTAMP)) AS io_min_lag,
  output_monthly_stats.output_active_months,
  output_monthly_stats.total_tx_output_count,
  output_monthly_stats.total_tx_output_value,
  output_monthly_stats.mean_tx_output_value,
  output_monthly_stats.stddev_tx_output_value,
  output_monthly_stats.total_output_tx,
  output_monthly_stats.mean_monthly_output_value,
  output_monthly_stats.mean_monthly_output_count,
  input_monthly_stats.input_active_months,
  input_monthly_stats.total_tx_input_count,
  input_monthly_stats.total_tx_input_value,
  input_monthly_stats.mean_tx_input_value,
  input_monthly_stats.stddev_tx_input_value,
  input_monthly_stats.total_input_tx,
  input_monthly_stats.mean_monthly_input_value,
  input_monthly_stats.mean_monthly_input_count,
  output_idle_times.mean_output_idle_time,
  output_idle_times.stddev_output_idle_time,
  input_idle_times.mean_input_idle_time,
  input_idle_times.stddev_input_idle_time
FROM
  output_ages, output_monthly_stats, output_idle_times,
  input_ages,  input_monthly_stats, input_idle_times
WHERE TRUE
  AND output_ages.output_ages_address = output_monthly_stats.output_monthly_stats_address
  AND output_ages.output_ages_address = output_idle_times.idle_time_address
  AND output_ages.output_ages_address = input_monthly_stats.input_monthly_stats_address
  AND output_ages.output_ages_address = input_ages.input_ages_address
  AND output_ages.output_ages_address = input_idle_times.idle_time_address
  AND output_ages.output_ages_address NOT IN
(
  SELECT 
    ARRAY_TO_STRING(outputs.addresses,',') AS miner
  FROM 
  `bigquery-public-data.crypto_bitcoin.blocks` AS blocks,
  `bigquery-public-data.crypto_bitcoin.transactions` AS transactions JOIN UNNEST(outputs) AS outputs
  WHERE blocks.hash = transactions.block_hash 
    AND is_coinbase IS TRUE
    AND ( FALSE
      --
      -- miner signatures from https://en.bitcoin.it/wiki/Comparison_of_mining_pools
      --
      OR coinbase_param LIKE '%4d696e656420627920416e74506f6f6c%' --AntPool
      OR coinbase_param LIKE '%2f42434d6f6e737465722f%' --BCMonster
      --BitcoinAffiliateNetwork
      OR coinbase_param LIKE '%4269744d696e746572%' --BitMinter
      --BTC.com
      --BTCC Pool
      --BTCDig
      OR coinbase_param LIKE '%2f7374726174756d2f%' --Btcmp
      --btcZPool.com
      --BW Mining
      OR coinbase_param LIKE '%456c6967697573%' --Eligius
      --F2Pool
      --GHash.IO
      --Give Me COINS
      --Golden Nonce Pool
      OR coinbase_param LIKE '%2f627261766f2d6d696e696e672f%' --Bravo Mining
      OR coinbase_param LIKE '%4b616e6f%' --KanoPool
      --kmdPool.org
      OR coinbase_param LIKE '%2f6d6d706f6f6c%' --Merge Mining Pool
      --MergeMining
      --Multipool
      --P2Pool
      OR coinbase_param LIKE '%2f736c7573682f%' --Slush Pool
      --ZenPool.org
    )
  GROUP BY miner
  HAVING COUNT(1) >= 20 
)
LIMIT {})
'''.format(miner_limit, non_miner_limit)

# %%
df = client.query(sql).to_dataframe()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 30 columns):
# is_miner                     10000 non-null bool
# address                      10000 non-null object
# output_month_min             10000 non-null int64
# output_month_max             10000 non-null int64
# input_month_min              10000 non-null int64
# input_month_max              10000 non-null int64
# output_active_time           10000 non-null int64
# input_active_time            10000 non-null int64
# io_max_lag                   10000 non-null int64
# io_min_lag                   10000 non-null int64
# output_active_months         10000 non-null int64
# total_tx_output_count        10000 non-null int64
# total_tx_output_value        10000 non-null object
# mean_tx_output_value         10000 non-null object
# stddev_tx_output_value       10000 non-null float64
# total_output_tx              10000 non-null int64
# mean_monthly_output_value    10000 non-null object
# mean_monthly_output_count    10000 non-null float64
# input_active_months          10000 non-null int64
# total_tx_input_count         10000 non-null int64
# total_tx_input_value         10000 non-null object
# mean_tx_input_value          10000 non-null object
# stddev_tx_input_value        10000 non-null float64
# total_input_tx               10000 non-null int64
# mean_monthly_input_value     10000 non-null object
# mean_monthly_input_count     10000 non-null float64
# mean_output_idle_time        10000 non-null float64
# stddev_output_idle_time      8085 non-null float64
# mean_input_idle_time         10000 non-null float64
# stddev_input_idle_time       7615 non-null float64
# dtypes: bool(1), float64(8), int64(14), object(7)
# memory usage: 2.2+ MB

# %%
# Dropping the columns with null values
df.drop(labels = ['stddev_output_idle_time','stddev_input_idle_time'], axis = 1, inplace = True)

# %%
df.tail(5)
# Out:
#       is_miner                             address  output_month_min  \
# 9995      True   1JkGTGhudeoGY4kaTChYJz3w2xM6ENEi8        1306886400
# 9996      True  1N1UD4nxJy5ojiP954GCuMzvQwXcZU9VZQ        1383264000
# 9997     False  1NbQxX4BEJbftjPYJhtdNAQR3tJ69rHkqL        1561939200
# 9998     False  1NMvLc9M3H5ix6SCft5K8wPB9qrZrqvDyb        1477958400
# 9999     False  39kDzMm6WKDDLo1zuYGF3inHW799dGmWRB        1485907200
#
#       output_month_max  input_month_min  input_month_max  output_active_time  \
# 9995        1322697600       1309478400       1330560000            15811200
# 9996        1404172800       1393632000       1433116800            20908800
# 9997        1561939200       1561939200       1561939200                   0
# 9998        1556668800       1483228800       1556668800            78710400
# 9999        1530403200       1485907200       1530403200            44496000
#
#       input_active_time  io_max_lag  io_min_lag  ...  input_active_months  \
# 9995           21081600    -7862400    -2592000  ...                    8
# 9996           39484800   -28944000   -10368000  ...                    3
# 9997                  0           0           0  ...                    1
# 9998           73440000           0    -5270400  ...                    8
# 9999           44496000           0           0  ...                   16
#
#       total_tx_input_count total_tx_input_value mean_tx_input_value  \
# 9995                    52           2902107025  55809750.480769231
# 9996                    51            284994932   5588135.921568627
# 9997                    52             14028651           269781.75
# 9998                    29             40900859   1410374.448275862
# 9999                    52             38841359    746949.211538462
#
#       stddev_tx_input_value  total_input_tx mean_monthly_input_value  \
# 9995           2.807831e+07              24       55809750.480769231
# 9996           3.529053e+06               3        5588135.921568627
# 9997           1.029258e+04              52                269781.75
# 9998           1.378818e+06              23        1410374.448275862
# 9999           5.983542e+05              48         746949.211538462
#
#       mean_monthly_input_count  mean_output_idle_time  mean_input_idle_time
# 9995                       1.0           2.720730e+05          9.922699e+05
# 9996                       1.0           3.851943e+05          1.956094e+07
# 9997                       1.0           6.423846e+02          6.804167e+02
# 9998                       1.0           1.885750e+06          3.764659e+06
# 9999                       1.0           9.235895e+05          9.329199e+05
#
# [5 rows x 28 columns]

# %%
df.head(5)
# Out:
#    is_miner                             address  output_month_min  \
# 0      True  16C4Q1oHKoHwLoiou2zgCZfY2Pj9avKqqx        1306886400
# 1      True  1N4DuZWCzanta6L1QqsfzMBZuhFdjQoEvd        1393632000
# 2      True  1HotSWAPvmFXeUHKxq5tqQCswdTxaRzxvY        1383264000
# 3      True  1F79xJLcp1grhNAS8xuurQryNpNocg2uHo        1393632000
# 4      True   1pZTRmdTtorqZnYhHpT4DW4owjZ8mBNyQ        1325376000
#
#    output_month_max  input_month_min  input_month_max  output_active_time  \
# 0        1354320000       1306886400       1383264000            47433600
# 1        1438387200       1398902400       1401580800            44755200
# 2        1561939200       1383264000       1559347200           178675200
# 3        1430438400       1401580800       1425168000            36806400
# 4        1422748800       1325376000       1409529600            97372800
#
#    input_active_time  io_max_lag  io_min_lag  ...  input_active_months  \
# 0           76377600   -28944000           0  ...                   12
# 1            2678400    36806400    -5270400  ...                    2
# 2          176083200     2592000           0  ...                   27
# 3           23587200     5270400    -7948800  ...                    5
# 4           84153600    13219200           0  ...                   14
#
#    total_tx_input_count total_tx_input_value  mean_tx_input_value  \
# 0                   236          27592179549  116916015.038135593
# 1                    39            661080753   16950788.538461538
# 2                  1569           5984297976    3814084.114722753
# 3                    59            341610136    5790002.305084746
# 4                   463         127561458645  275510709.816414687
#
#    stddev_tx_input_value  total_input_tx mean_monthly_input_value  \
# 0           8.356683e+07              18      116916015.038135593
# 1           9.269358e+06               5       16950788.538461538
# 2           2.814267e+07             115        3814084.114722753
# 3           2.388470e+06              12        5790002.305084746
# 4           2.476178e+09              34      275510709.816414687
#
#    mean_monthly_input_count  mean_output_idle_time  mean_input_idle_time
# 0                       1.0          196875.770213          4.477175e+06
# 1                       1.0          665774.909091          5.828208e+05
# 2                       1.0          117317.039843          1.700041e+06
# 3                       1.0          630305.065574          2.315492e+06
# 4                       1.0          212523.327511          2.529585e+06
#
# [5 rows x 28 columns]

# %%
df.shape
# Out:
# (10000, 28)

# %%
# Dropping the non-numeric features
features = df.drop(labels = ['is_miner', 'address'], axis = 1)
target = df['is_miner'].values
indices = range(len(features))

# %% [markdown]
# ## t-SNE

# %%
sns.set_style('darkgrid')
sns.set_palette('muted')
sns.set_context("notebook", font_scale = 1.5, rc = {"lines.linewidth": 2.5})

# %%
# Utility function to visualize the outputs of t-SNE
def bitcoin_scatter(x, colors):
    # choose a color palette with seaborn.
    num_classes = len(np.unique(colors))
    palette = np.array(sns.color_palette("hls", num_classes))

    # create a scatter plot.
    f = plt.figure(figsize = (8, 8))
    ax = plt.subplot(aspect = 'equal')
    sc = ax.scatter(x[:,0], x[:,1], lw = 0, s = 40, c=palette[colors.astype(np.int)])
    plt.xlim(-25, 25)
    plt.ylim(-25, 25)
    ax.axis('off')
    ax.axis('tight')
    plt.title('t-SNE to visualize features')

    # add the labels for each digit corresponding to the label
    txts = []

    for i in range(num_classes):

        # Position of each label at median of data points.

        xtext, ytext = np.median(x[colors == i, :], axis = 0)
        txt = ax.text(xtext, ytext, str(i), fontsize = 24)
        txt.set_path_effects([
            PathEffects.Stroke(linewidth = 5, foreground = "w"),
            PathEffects.Normal()])
        txts.append(txt)

    return f, ax, sc, txts

# %%
time_start = time.time()
RS = 123
bitcoin_tsne = TSNE(random_state = RS).fit_transform(features)
print('Time elapsed: {} seconds' .format(time.time() - time_start))
# Out:
# Time elapsed: 73.04976296424866 seconds

# %%
bitcoin_scatter(bitcoin_tsne, target)
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f2d2a4bc5c0>,
#  <matplotlib.collections.PathCollection at 0x7f2d29e306d8>,
#  [Text(18.335135, -22.91592, '0'), Text(-30.855831, 27.944536, '1')])

# %%
plt.savefig('tSNE.jpg')

# %% [markdown]
# ## Splitting the training and testing dataset

# %%
# Splitting the training and testing dataset
x_train, x_test, y_train, y_test, indices_train, indices_test = train_test_split(features, target, indices,  test_size = 0.2)

# %%
x_train.head()
# Out:
#       output_month_min  output_month_max  input_month_min  input_month_max  \
# 2807        1349049600        1509494400       1377993600       1509494400
# 8883        1435708800        1493596800       1443657600       1501545600
# 2887        1370044800        1451606400       1370044800       1454284800
# 458         1398902400        1512086400       1401580800       1512086400
# 1323        1375315200        1383264000       1375315200       1383264000
#
#       output_active_time  input_active_time  io_max_lag  io_min_lag  \
# 2807           160444800          131500800           0   -28944000
# 8883            57888000           57888000    -7948800    -7948800
# 2887            81561600           84240000    -2678400           0
# 458            113184000          110505600           0    -2678400
# 1323             7948800            7948800           0           0
#
#       output_active_months  total_tx_output_count  ... input_active_months  \
# 2807                    23                    261  ...                   9
# 8883                    15                     26  ...                   2
# 2887                    15                     93  ...                   6
# 458                     29                    158  ...                   7
# 1323                     4                     22  ...                   4
#
#      total_tx_input_count  total_tx_input_value  mean_tx_input_value  \
# 2807                  260            2215329243    8520497.088461538
# 8883                   26             100993943    3884382.423076923
# 2887                   93            1457168608   15668479.655913978
# 458                   156             970260806    6219620.551282051
# 1323                   22             403563816   18343809.818181818
#
#      stddev_tx_input_value  total_input_tx  mean_monthly_input_value  \
# 2807          2.483580e+07              53         8520497.088461538
# 8883          1.114274e+06               2         3884382.423076923
# 2887          8.228897e+07               6        15668479.655913978
# 458           3.417315e+06              12         6219620.551282051
# 1323          5.612260e+06               5        18343809.818181818
#
#       mean_monthly_input_count mean_output_idle_time mean_input_idle_time
# 2807                       1.0          6.348941e+05         2.612695e+06
# 8883                       1.0          2.396664e+06         5.713088e+07
# 2887                       1.0          9.001891e+05         1.656929e+07
# 458                        1.0          7.319449e+05         1.237451e+07
# 1323                       1.0          3.119398e+05         1.882825e+06
#
# [5 rows x 26 columns]

# %%
x_train.shape
# Out:
# (8000, 26)

# %%
y_train
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %% [markdown]
# ## Artificial Neural Network

# %%
# Feature Scaling
sc_x = StandardScaler()
x_train_ann = sc_x.fit_transform(x_train)
x_test_ann = sc_x.transform(x_test)

# %%
num_classes = 2

# Hyperparameters
learn_rate = 0.001
batch_size = 500
epochs = 270

# %%
# Encoding the Dependent Variable
labelencoder_y = LabelEncoder()
y_train_ann = labelencoder_y.fit_transform(y_train)

# Converting to binary class matrix
y_train_ann = utils.to_categorical(y_train_ann, num_classes)

# %%
y_train_ann.shape
# Out:
# (8000, 2)

# %%
# Encoding the Dependent Variable
labelencoder_y = LabelEncoder()
y_test_ann = labelencoder_y.fit_transform(y_test)

# Converting to binary class matrix
y_test_ann = utils.to_categorical(y_test_ann, num_classes)

# %%
y_test_ann.shape
# Out:
# (2000, 2)

# %%
seed = 1
np.random.seed(seed)

# Creating model
ann = Sequential()
ann.add(Dense(26, activation = 'tanh', kernel_initializer = 'glorot_uniform'))
ann.add(Dense(11, activation = 'tanh'))
ann.add(Dropout(0.5))
ann.add(Dense(6, activation = 'tanh'))
ann.add(Dense(num_classes, activation = 'softmax'))

# %%
rmsprop = optimizers.RMSprop(learn_rate)
ann.compile(loss = 'binary_crossentropy', optimizer = rmsprop, metrics = ['binary_accuracy']) # Compiling the model

# %%
# Model fitting
ann.fit(np.array(x_train_ann), y_train_ann, batch_size = batch_size, epochs = epochs, validation_data = (x_test_ann, y_test_ann))
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/270
# 8000/8000 [==============================] - 4s 465us/step - loss: 0.4695 - binary_accuracy: 0.8104 - val_loss: 0.3208 - val_binary_accuracy: 0.9240
# Epoch 2/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.3242 - binary_accuracy: 0.9054 - val_loss: 0.2461 - val_binary_accuracy: 0.9305
# Epoch 3/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.2666 - binary_accuracy: 0.9235 - val_loss: 0.2073 - val_binary_accuracy: 0.9375
# Epoch 4/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.2255 - binary_accuracy: 0.9355 - val_loss: 0.1834 - val_binary_accuracy: 0.9440
# Epoch 5/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.1986 - binary_accuracy: 0.9425 - val_loss: 0.1682 - val_binary_accuracy: 0.9455
# Epoch 6/270
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.1803 - binary_accuracy: 0.9456 - val_loss: 0.1582 - val_binary_accuracy: 0.9500
# Epoch 7/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.1637 - binary_accuracy: 0.9486 - val_loss: 0.1493 - val_binary_accuracy: 0.9550
# Epoch 8/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.1503 - binary_accuracy: 0.9530 - val_loss: 0.1416 - val_binary_accuracy: 0.9570
# Epoch 9/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.1429 - binary_accuracy: 0.9560 - val_loss: 0.1359 - val_binary_accuracy: 0.9600
# Epoch 10/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.1330 - binary_accuracy: 0.9582 - val_loss: 0.1296 - val_binary_accuracy: 0.9615
# Epoch 11/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.1257 - binary_accuracy: 0.9623 - val_loss: 0.1254 - val_binary_accuracy: 0.9630
# Epoch 12/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.1164 - binary_accuracy: 0.9664 - val_loss: 0.1209 - val_binary_accuracy: 0.9660
# Epoch 13/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.1122 - binary_accuracy: 0.9664 - val_loss: 0.1169 - val_binary_accuracy: 0.9660
# Epoch 14/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.1055 - binary_accuracy: 0.9714 - val_loss: 0.1102 - val_binary_accuracy: 0.9700
# Epoch 15/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.1019 - binary_accuracy: 0.9711 - val_loss: 0.1076 - val_binary_accuracy: 0.9680
# Epoch 16/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0953 - binary_accuracy: 0.9754 - val_loss: 0.1031 - val_binary_accuracy: 0.9700
# Epoch 17/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0942 - binary_accuracy: 0.9745 - val_loss: 0.0995 - val_binary_accuracy: 0.9735
# Epoch 18/270
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.0911 - binary_accuracy: 0.9755 - val_loss: 0.0979 - val_binary_accuracy: 0.9745
# Epoch 19/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0896 - binary_accuracy: 0.9771 - val_loss: 0.0948 - val_binary_accuracy: 0.9740
# Epoch 20/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0896 - binary_accuracy: 0.9764 - val_loss: 0.0928 - val_binary_accuracy: 0.9730
# Epoch 21/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0849 - binary_accuracy: 0.9779 - val_loss: 0.0906 - val_binary_accuracy: 0.9745
# Epoch 22/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0840 - binary_accuracy: 0.9793 - val_loss: 0.0895 - val_binary_accuracy: 0.9745
# Epoch 23/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0842 - binary_accuracy: 0.9788 - val_loss: 0.0875 - val_binary_accuracy: 0.9755
# Epoch 24/270
# 8000/8000 [==============================] - 0s 10us/step - loss: 0.0784 - binary_accuracy: 0.9780 - val_loss: 0.0844 - val_binary_accuracy: 0.9755
# Epoch 25/270
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.0810 - binary_accuracy: 0.9775 - val_loss: 0.0837 - val_binary_accuracy: 0.9735
# Epoch 26/270
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.0771 - binary_accuracy: 0.9778 - val_loss: 0.0809 - val_binary_accuracy: 0.9765
# Epoch 27/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0782 - binary_accuracy: 0.9791 - val_loss: 0.0812 - val_binary_accuracy: 0.9775
# Epoch 28/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0797 - binary_accuracy: 0.9783 - val_loss: 0.0818 - val_binary_accuracy: 0.9755
# Epoch 29/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0766 - binary_accuracy: 0.9794 - val_loss: 0.0796 - val_binary_accuracy: 0.9785
# Epoch 30/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0752 - binary_accuracy: 0.9803 - val_loss: 0.0772 - val_binary_accuracy: 0.9790
# Epoch 31/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0771 - binary_accuracy: 0.9800 - val_loss: 0.0779 - val_binary_accuracy: 0.9765
# Epoch 32/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0774 - binary_accuracy: 0.9794 - val_loss: 0.0766 - val_binary_accuracy: 0.9765
# Epoch 33/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0758 - binary_accuracy: 0.9798 - val_loss: 0.0789 - val_binary_accuracy: 0.9800
# Epoch 34/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0757 - binary_accuracy: 0.9806 - val_loss: 0.0766 - val_binary_accuracy: 0.9770
# Epoch 35/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0740 - binary_accuracy: 0.9806 - val_loss: 0.0746 - val_binary_accuracy: 0.9780
# Epoch 36/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0739 - binary_accuracy: 0.9804 - val_loss: 0.0749 - val_binary_accuracy: 0.9790
# Epoch 37/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0735 - binary_accuracy: 0.9810 - val_loss: 0.0755 - val_binary_accuracy: 0.9775
# Epoch 38/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0712 - binary_accuracy: 0.9810 - val_loss: 0.0742 - val_binary_accuracy: 0.9800
# Epoch 39/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0726 - binary_accuracy: 0.9801 - val_loss: 0.0741 - val_binary_accuracy: 0.9790
# Epoch 40/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0731 - binary_accuracy: 0.9804 - val_loss: 0.0740 - val_binary_accuracy: 0.9795
# Epoch 41/270
# 8000/8000 [==============================] - 0s 10us/step - loss: 0.0695 - binary_accuracy: 0.9814 - val_loss: 0.0734 - val_binary_accuracy: 0.9785
# Epoch 42/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0715 - binary_accuracy: 0.9806 - val_loss: 0.0727 - val_binary_accuracy: 0.9785
# Epoch 43/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0706 - binary_accuracy: 0.9812 - val_loss: 0.0728 - val_binary_accuracy: 0.9800
# Epoch 44/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0699 - binary_accuracy: 0.9819 - val_loss: 0.0718 - val_binary_accuracy: 0.9780
# Epoch 45/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0707 - binary_accuracy: 0.9814 - val_loss: 0.0720 - val_binary_accuracy: 0.9780
# Epoch 46/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0694 - binary_accuracy: 0.9815 - val_loss: 0.0718 - val_binary_accuracy: 0.9780
# Epoch 47/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0703 - binary_accuracy: 0.9808 - val_loss: 0.0725 - val_binary_accuracy: 0.9815
# Epoch 48/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0653 - binary_accuracy: 0.9830 - val_loss: 0.0704 - val_binary_accuracy: 0.9810
# Epoch 49/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0679 - binary_accuracy: 0.9820 - val_loss: 0.0702 - val_binary_accuracy: 0.9795
# Epoch 50/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0683 - binary_accuracy: 0.9823 - val_loss: 0.0712 - val_binary_accuracy: 0.9780
# Epoch 51/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0697 - binary_accuracy: 0.9805 - val_loss: 0.0748 - val_binary_accuracy: 0.9755
# Epoch 52/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0691 - binary_accuracy: 0.9819 - val_loss: 0.0698 - val_binary_accuracy: 0.9785
# Epoch 53/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0671 - binary_accuracy: 0.9815 - val_loss: 0.0690 - val_binary_accuracy: 0.9800
# Epoch 54/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0669 - binary_accuracy: 0.9825 - val_loss: 0.0699 - val_binary_accuracy: 0.9800
# Epoch 55/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0688 - binary_accuracy: 0.9818 - val_loss: 0.0697 - val_binary_accuracy: 0.9815
# Epoch 56/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0673 - binary_accuracy: 0.9824 - val_loss: 0.0693 - val_binary_accuracy: 0.9805
# Epoch 57/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0676 - binary_accuracy: 0.9817 - val_loss: 0.0689 - val_binary_accuracy: 0.9790
# Epoch 58/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0661 - binary_accuracy: 0.9818 - val_loss: 0.0710 - val_binary_accuracy: 0.9765
# Epoch 59/270
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.0670 - binary_accuracy: 0.9820 - val_loss: 0.0683 - val_binary_accuracy: 0.9795
# Epoch 60/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0697 - binary_accuracy: 0.9818 - val_loss: 0.0675 - val_binary_accuracy: 0.9810
# Epoch 61/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0671 - binary_accuracy: 0.9819 - val_loss: 0.0678 - val_binary_accuracy: 0.9805
# Epoch 62/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0670 - binary_accuracy: 0.9814 - val_loss: 0.0679 - val_binary_accuracy: 0.9805
# Epoch 63/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0656 - binary_accuracy: 0.9825 - val_loss: 0.0683 - val_binary_accuracy: 0.9800
# Epoch 64/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0651 - binary_accuracy: 0.9821 - val_loss: 0.0669 - val_binary_accuracy: 0.9800
# Epoch 65/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0661 - binary_accuracy: 0.9829 - val_loss: 0.0665 - val_binary_accuracy: 0.9800
# Epoch 66/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0642 - binary_accuracy: 0.9821 - val_loss: 0.0671 - val_binary_accuracy: 0.9815
# Epoch 67/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0656 - binary_accuracy: 0.9830 - val_loss: 0.0665 - val_binary_accuracy: 0.9805
# Epoch 68/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0642 - binary_accuracy: 0.9826 - val_loss: 0.0653 - val_binary_accuracy: 0.9815
# Epoch 69/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0656 - binary_accuracy: 0.9816 - val_loss: 0.0682 - val_binary_accuracy: 0.9810
# Epoch 70/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0643 - binary_accuracy: 0.9827 - val_loss: 0.0650 - val_binary_accuracy: 0.9810
# Epoch 71/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0643 - binary_accuracy: 0.9826 - val_loss: 0.0667 - val_binary_accuracy: 0.9790
# Epoch 72/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0655 - binary_accuracy: 0.9822 - val_loss: 0.0651 - val_binary_accuracy: 0.9810
# Epoch 73/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0640 - binary_accuracy: 0.9824 - val_loss: 0.0652 - val_binary_accuracy: 0.9805
# Epoch 74/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0643 - binary_accuracy: 0.9831 - val_loss: 0.0663 - val_binary_accuracy: 0.9790
# Epoch 75/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0661 - binary_accuracy: 0.9830 - val_loss: 0.0671 - val_binary_accuracy: 0.9805
# Epoch 76/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0663 - binary_accuracy: 0.9821 - val_loss: 0.0658 - val_binary_accuracy: 0.9810
# Epoch 77/270
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.0655 - binary_accuracy: 0.9825 - val_loss: 0.0672 - val_binary_accuracy: 0.9785
# Epoch 78/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0609 - binary_accuracy: 0.9831 - val_loss: 0.0644 - val_binary_accuracy: 0.9800
# Epoch 79/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0657 - binary_accuracy: 0.9822 - val_loss: 0.0663 - val_binary_accuracy: 0.9800
# Epoch 80/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0630 - binary_accuracy: 0.9838 - val_loss: 0.0659 - val_binary_accuracy: 0.9795
# Epoch 81/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0626 - binary_accuracy: 0.9833 - val_loss: 0.0639 - val_binary_accuracy: 0.9830
# Epoch 82/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0630 - binary_accuracy: 0.9835 - val_loss: 0.0656 - val_binary_accuracy: 0.9790
# Epoch 83/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0618 - binary_accuracy: 0.9844 - val_loss: 0.0647 - val_binary_accuracy: 0.9805
# Epoch 84/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0628 - binary_accuracy: 0.9825 - val_loss: 0.0631 - val_binary_accuracy: 0.9825
# Epoch 85/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0614 - binary_accuracy: 0.9845 - val_loss: 0.0656 - val_binary_accuracy: 0.9795
# Epoch 86/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0625 - binary_accuracy: 0.9834 - val_loss: 0.0628 - val_binary_accuracy: 0.9830
# Epoch 87/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0605 - binary_accuracy: 0.9839 - val_loss: 0.0645 - val_binary_accuracy: 0.9800
# Epoch 88/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0616 - binary_accuracy: 0.9831 - val_loss: 0.0633 - val_binary_accuracy: 0.9825
# Epoch 89/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0625 - binary_accuracy: 0.9832 - val_loss: 0.0633 - val_binary_accuracy: 0.9825
# Epoch 90/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0612 - binary_accuracy: 0.9843 - val_loss: 0.0628 - val_binary_accuracy: 0.9820
# Epoch 91/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0612 - binary_accuracy: 0.9842 - val_loss: 0.0631 - val_binary_accuracy: 0.9825
# Epoch 92/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0581 - binary_accuracy: 0.9846 - val_loss: 0.0637 - val_binary_accuracy: 0.9815
# Epoch 93/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0621 - binary_accuracy: 0.9835 - val_loss: 0.0632 - val_binary_accuracy: 0.9815
# Epoch 94/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0623 - binary_accuracy: 0.9831 - val_loss: 0.0635 - val_binary_accuracy: 0.9820
# Epoch 95/270
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.0612 - binary_accuracy: 0.9846 - val_loss: 0.0630 - val_binary_accuracy: 0.9815
# Epoch 96/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0602 - binary_accuracy: 0.9837 - val_loss: 0.0635 - val_binary_accuracy: 0.9810
# Epoch 97/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0612 - binary_accuracy: 0.9845 - val_loss: 0.0629 - val_binary_accuracy: 0.9810
# Epoch 98/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0589 - binary_accuracy: 0.9845 - val_loss: 0.0642 - val_binary_accuracy: 0.9820
# Epoch 99/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0609 - binary_accuracy: 0.9828 - val_loss: 0.0644 - val_binary_accuracy: 0.9795
# Epoch 100/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0627 - binary_accuracy: 0.9824 - val_loss: 0.0634 - val_binary_accuracy: 0.9805
# Epoch 101/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0594 - binary_accuracy: 0.9833 - val_loss: 0.0634 - val_binary_accuracy: 0.9810
# Epoch 102/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0618 - binary_accuracy: 0.9834 - val_loss: 0.0635 - val_binary_accuracy: 0.9815
# Epoch 103/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0598 - binary_accuracy: 0.9846 - val_loss: 0.0621 - val_binary_accuracy: 0.9830
# Epoch 104/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0596 - binary_accuracy: 0.9849 - val_loss: 0.0639 - val_binary_accuracy: 0.9830
# Epoch 105/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0590 - binary_accuracy: 0.9846 - val_loss: 0.0619 - val_binary_accuracy: 0.9820
# Epoch 106/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0603 - binary_accuracy: 0.9838 - val_loss: 0.0625 - val_binary_accuracy: 0.9810
# Epoch 107/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0592 - binary_accuracy: 0.9839 - val_loss: 0.0620 - val_binary_accuracy: 0.9815
# Epoch 108/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0588 - binary_accuracy: 0.9851 - val_loss: 0.0626 - val_binary_accuracy: 0.9815
# Epoch 109/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0584 - binary_accuracy: 0.9852 - val_loss: 0.0615 - val_binary_accuracy: 0.9815
# Epoch 110/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0603 - binary_accuracy: 0.9839 - val_loss: 0.0628 - val_binary_accuracy: 0.9820
# Epoch 111/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0584 - binary_accuracy: 0.9840 - val_loss: 0.0627 - val_binary_accuracy: 0.9815
# Epoch 112/270
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.0578 - binary_accuracy: 0.9847 - val_loss: 0.0610 - val_binary_accuracy: 0.9830
# Epoch 113/270
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.0589 - binary_accuracy: 0.9836 - val_loss: 0.0620 - val_binary_accuracy: 0.9825
# Epoch 114/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0591 - binary_accuracy: 0.9844 - val_loss: 0.0623 - val_binary_accuracy: 0.9805
# Epoch 115/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0606 - binary_accuracy: 0.9834 - val_loss: 0.0622 - val_binary_accuracy: 0.9815
# Epoch 116/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0585 - binary_accuracy: 0.9846 - val_loss: 0.0623 - val_binary_accuracy: 0.9805
# Epoch 117/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0580 - binary_accuracy: 0.9845 - val_loss: 0.0601 - val_binary_accuracy: 0.9830
# Epoch 118/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0590 - binary_accuracy: 0.9846 - val_loss: 0.0622 - val_binary_accuracy: 0.9805
# Epoch 119/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0582 - binary_accuracy: 0.9848 - val_loss: 0.0621 - val_binary_accuracy: 0.9815
# Epoch 120/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0592 - binary_accuracy: 0.9835 - val_loss: 0.0614 - val_binary_accuracy: 0.9815
# Epoch 121/270
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.0576 - binary_accuracy: 0.9846 - val_loss: 0.0610 - val_binary_accuracy: 0.9825
# Epoch 122/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0584 - binary_accuracy: 0.9849 - val_loss: 0.0602 - val_binary_accuracy: 0.9830
# Epoch 123/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0592 - binary_accuracy: 0.9839 - val_loss: 0.0607 - val_binary_accuracy: 0.9825
# Epoch 124/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0576 - binary_accuracy: 0.9845 - val_loss: 0.0597 - val_binary_accuracy: 0.9825
# Epoch 125/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0554 - binary_accuracy: 0.9856 - val_loss: 0.0605 - val_binary_accuracy: 0.9830
# Epoch 126/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0591 - binary_accuracy: 0.9836 - val_loss: 0.0631 - val_binary_accuracy: 0.9810
# Epoch 127/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0566 - binary_accuracy: 0.9848 - val_loss: 0.0608 - val_binary_accuracy: 0.9840
# Epoch 128/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0578 - binary_accuracy: 0.9852 - val_loss: 0.0603 - val_binary_accuracy: 0.9825
# Epoch 129/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0583 - binary_accuracy: 0.9849 - val_loss: 0.0599 - val_binary_accuracy: 0.9815
# Epoch 130/270
# 8000/8000 [==============================] - 0s 10us/step - loss: 0.0576 - binary_accuracy: 0.9841 - val_loss: 0.0606 - val_binary_accuracy: 0.9835
# Epoch 131/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0553 - binary_accuracy: 0.9850 - val_loss: 0.0589 - val_binary_accuracy: 0.9840
# Epoch 132/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0588 - binary_accuracy: 0.9844 - val_loss: 0.0600 - val_binary_accuracy: 0.9830
# Epoch 133/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0582 - binary_accuracy: 0.9840 - val_loss: 0.0593 - val_binary_accuracy: 0.9825
# Epoch 134/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0554 - binary_accuracy: 0.9861 - val_loss: 0.0602 - val_binary_accuracy: 0.9845
# Epoch 135/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0567 - binary_accuracy: 0.9853 - val_loss: 0.0601 - val_binary_accuracy: 0.9820
# Epoch 136/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0565 - binary_accuracy: 0.9850 - val_loss: 0.0604 - val_binary_accuracy: 0.9825
# Epoch 137/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0554 - binary_accuracy: 0.9858 - val_loss: 0.0619 - val_binary_accuracy: 0.9830
# Epoch 138/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0554 - binary_accuracy: 0.9863 - val_loss: 0.0582 - val_binary_accuracy: 0.9845
# Epoch 139/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0563 - binary_accuracy: 0.9853 - val_loss: 0.0598 - val_binary_accuracy: 0.9820
# Epoch 140/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0568 - binary_accuracy: 0.9842 - val_loss: 0.0622 - val_binary_accuracy: 0.9830
# Epoch 141/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0572 - binary_accuracy: 0.9851 - val_loss: 0.0583 - val_binary_accuracy: 0.9835
# Epoch 142/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0575 - binary_accuracy: 0.9854 - val_loss: 0.0588 - val_binary_accuracy: 0.9830
# Epoch 143/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0572 - binary_accuracy: 0.9855 - val_loss: 0.0579 - val_binary_accuracy: 0.9840
# Epoch 144/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0559 - binary_accuracy: 0.9849 - val_loss: 0.0585 - val_binary_accuracy: 0.9835
# Epoch 145/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0565 - binary_accuracy: 0.9850 - val_loss: 0.0576 - val_binary_accuracy: 0.9840
# Epoch 146/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0567 - binary_accuracy: 0.9846 - val_loss: 0.0572 - val_binary_accuracy: 0.9840
# Epoch 147/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0562 - binary_accuracy: 0.9851 - val_loss: 0.0582 - val_binary_accuracy: 0.9835
# Epoch 148/270
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.0526 - binary_accuracy: 0.9854 - val_loss: 0.0578 - val_binary_accuracy: 0.9830
# Epoch 149/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0556 - binary_accuracy: 0.9864 - val_loss: 0.0608 - val_binary_accuracy: 0.9815
# Epoch 150/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0550 - binary_accuracy: 0.9860 - val_loss: 0.0577 - val_binary_accuracy: 0.9840
# Epoch 151/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0542 - binary_accuracy: 0.9860 - val_loss: 0.0581 - val_binary_accuracy: 0.9830
# Epoch 152/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0554 - binary_accuracy: 0.9858 - val_loss: 0.0580 - val_binary_accuracy: 0.9835
# Epoch 153/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0549 - binary_accuracy: 0.9857 - val_loss: 0.0571 - val_binary_accuracy: 0.9840
# Epoch 154/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0551 - binary_accuracy: 0.9864 - val_loss: 0.0572 - val_binary_accuracy: 0.9845
# Epoch 155/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0555 - binary_accuracy: 0.9854 - val_loss: 0.0572 - val_binary_accuracy: 0.9830
# Epoch 156/270
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.0562 - binary_accuracy: 0.9854 - val_loss: 0.0581 - val_binary_accuracy: 0.9825
# Epoch 157/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0556 - binary_accuracy: 0.9852 - val_loss: 0.0573 - val_binary_accuracy: 0.9840
# Epoch 158/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0555 - binary_accuracy: 0.9859 - val_loss: 0.0596 - val_binary_accuracy: 0.9820
# Epoch 159/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0542 - binary_accuracy: 0.9860 - val_loss: 0.0588 - val_binary_accuracy: 0.9815
# Epoch 160/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0555 - binary_accuracy: 0.9846 - val_loss: 0.0601 - val_binary_accuracy: 0.9840
# Epoch 161/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0554 - binary_accuracy: 0.9851 - val_loss: 0.0583 - val_binary_accuracy: 0.9830
# Epoch 162/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0526 - binary_accuracy: 0.9867 - val_loss: 0.0572 - val_binary_accuracy: 0.9845
# Epoch 163/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0549 - binary_accuracy: 0.9861 - val_loss: 0.0595 - val_binary_accuracy: 0.9835
# Epoch 164/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0547 - binary_accuracy: 0.9851 - val_loss: 0.0604 - val_binary_accuracy: 0.9815
# Epoch 165/270
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.0538 - binary_accuracy: 0.9854 - val_loss: 0.0629 - val_binary_accuracy: 0.9835
# Epoch 166/270
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.0546 - binary_accuracy: 0.9856 - val_loss: 0.0576 - val_binary_accuracy: 0.9835
# Epoch 167/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0541 - binary_accuracy: 0.9863 - val_loss: 0.0574 - val_binary_accuracy: 0.9830
# Epoch 168/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0548 - binary_accuracy: 0.9858 - val_loss: 0.0567 - val_binary_accuracy: 0.9835
# Epoch 169/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0532 - binary_accuracy: 0.9866 - val_loss: 0.0574 - val_binary_accuracy: 0.9820
# Epoch 170/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0552 - binary_accuracy: 0.9850 - val_loss: 0.0577 - val_binary_accuracy: 0.9835
# Epoch 171/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0547 - binary_accuracy: 0.9855 - val_loss: 0.0578 - val_binary_accuracy: 0.9830
# Epoch 172/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0525 - binary_accuracy: 0.9871 - val_loss: 0.0560 - val_binary_accuracy: 0.9845
# Epoch 173/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0543 - binary_accuracy: 0.9861 - val_loss: 0.0561 - val_binary_accuracy: 0.9840
# Epoch 174/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0552 - binary_accuracy: 0.9861 - val_loss: 0.0637 - val_binary_accuracy: 0.9830
# Epoch 175/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0527 - binary_accuracy: 0.9865 - val_loss: 0.0640 - val_binary_accuracy: 0.9800
# Epoch 176/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0538 - binary_accuracy: 0.9854 - val_loss: 0.0556 - val_binary_accuracy: 0.9850
# Epoch 177/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0526 - binary_accuracy: 0.9856 - val_loss: 0.0562 - val_binary_accuracy: 0.9840
# Epoch 178/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0527 - binary_accuracy: 0.9861 - val_loss: 0.0566 - val_binary_accuracy: 0.9830
# Epoch 179/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0552 - binary_accuracy: 0.9860 - val_loss: 0.0575 - val_binary_accuracy: 0.9820
# Epoch 180/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0529 - binary_accuracy: 0.9863 - val_loss: 0.0550 - val_binary_accuracy: 0.9845
# Epoch 181/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0541 - binary_accuracy: 0.9859 - val_loss: 0.0572 - val_binary_accuracy: 0.9845
# Epoch 182/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0545 - binary_accuracy: 0.9859 - val_loss: 0.0563 - val_binary_accuracy: 0.9855
# Epoch 183/270
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.0540 - binary_accuracy: 0.9861 - val_loss: 0.0567 - val_binary_accuracy: 0.9830
# Epoch 184/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0522 - binary_accuracy: 0.9866 - val_loss: 0.0556 - val_binary_accuracy: 0.9845
# Epoch 185/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0518 - binary_accuracy: 0.9869 - val_loss: 0.0576 - val_binary_accuracy: 0.9830
# Epoch 186/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0505 - binary_accuracy: 0.9873 - val_loss: 0.0555 - val_binary_accuracy: 0.9835
# Epoch 187/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0527 - binary_accuracy: 0.9865 - val_loss: 0.0583 - val_binary_accuracy: 0.9825
# Epoch 188/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0530 - binary_accuracy: 0.9867 - val_loss: 0.0556 - val_binary_accuracy: 0.9850
# Epoch 189/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0521 - binary_accuracy: 0.9867 - val_loss: 0.0560 - val_binary_accuracy: 0.9840
# Epoch 190/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0533 - binary_accuracy: 0.9871 - val_loss: 0.0565 - val_binary_accuracy: 0.9835
# Epoch 191/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0531 - binary_accuracy: 0.9864 - val_loss: 0.0557 - val_binary_accuracy: 0.9840
# Epoch 192/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0513 - binary_accuracy: 0.9870 - val_loss: 0.0565 - val_binary_accuracy: 0.9840
# Epoch 193/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0529 - binary_accuracy: 0.9861 - val_loss: 0.0556 - val_binary_accuracy: 0.9845
# Epoch 194/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0506 - binary_accuracy: 0.9870 - val_loss: 0.0556 - val_binary_accuracy: 0.9835
# Epoch 195/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0512 - binary_accuracy: 0.9875 - val_loss: 0.0568 - val_binary_accuracy: 0.9845
# Epoch 196/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0518 - binary_accuracy: 0.9869 - val_loss: 0.0579 - val_binary_accuracy: 0.9825
# Epoch 197/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0514 - binary_accuracy: 0.9867 - val_loss: 0.0574 - val_binary_accuracy: 0.9830
# Epoch 198/270
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.0526 - binary_accuracy: 0.9868 - val_loss: 0.0571 - val_binary_accuracy: 0.9840
# Epoch 199/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0525 - binary_accuracy: 0.9864 - val_loss: 0.0556 - val_binary_accuracy: 0.9840
# Epoch 200/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0527 - binary_accuracy: 0.9867 - val_loss: 0.0570 - val_binary_accuracy: 0.9830
# Epoch 201/270
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.0518 - binary_accuracy: 0.9874 - val_loss: 0.0574 - val_binary_accuracy: 0.9825
# Epoch 202/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0505 - binary_accuracy: 0.9874 - val_loss: 0.0559 - val_binary_accuracy: 0.9845
# Epoch 203/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0517 - binary_accuracy: 0.9865 - val_loss: 0.0553 - val_binary_accuracy: 0.9825
# Epoch 204/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0519 - binary_accuracy: 0.9873 - val_loss: 0.0558 - val_binary_accuracy: 0.9830
# Epoch 205/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0531 - binary_accuracy: 0.9866 - val_loss: 0.0549 - val_binary_accuracy: 0.9845
# Epoch 206/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0513 - binary_accuracy: 0.9876 - val_loss: 0.0605 - val_binary_accuracy: 0.9830
# Epoch 207/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0504 - binary_accuracy: 0.9866 - val_loss: 0.0566 - val_binary_accuracy: 0.9830
# Epoch 208/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0520 - binary_accuracy: 0.9870 - val_loss: 0.0627 - val_binary_accuracy: 0.9810
# Epoch 209/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0526 - binary_accuracy: 0.9865 - val_loss: 0.0578 - val_binary_accuracy: 0.9825
# Epoch 210/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0506 - binary_accuracy: 0.9870 - val_loss: 0.0548 - val_binary_accuracy: 0.9855
# Epoch 211/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0504 - binary_accuracy: 0.9870 - val_loss: 0.0563 - val_binary_accuracy: 0.9830
# Epoch 212/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0488 - binary_accuracy: 0.9883 - val_loss: 0.0559 - val_binary_accuracy: 0.9835
# Epoch 213/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0523 - binary_accuracy: 0.9865 - val_loss: 0.0555 - val_binary_accuracy: 0.9835
# Epoch 214/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0513 - binary_accuracy: 0.9869 - val_loss: 0.0558 - val_binary_accuracy: 0.9835
# Epoch 215/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0512 - binary_accuracy: 0.9861 - val_loss: 0.0555 - val_binary_accuracy: 0.9835
# Epoch 216/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0496 - binary_accuracy: 0.9866 - val_loss: 0.0561 - val_binary_accuracy: 0.9825
# Epoch 217/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0509 - binary_accuracy: 0.9869 - val_loss: 0.0553 - val_binary_accuracy: 0.9835
# Epoch 218/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0517 - binary_accuracy: 0.9865 - val_loss: 0.0540 - val_binary_accuracy: 0.9840
# Epoch 219/270
# 8000/8000 [==============================] - 0s 9us/step - loss: 0.0505 - binary_accuracy: 0.9870 - val_loss: 0.0547 - val_binary_accuracy: 0.9840
# Epoch 220/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0513 - binary_accuracy: 0.9879 - val_loss: 0.0551 - val_binary_accuracy: 0.9835
# Epoch 221/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0505 - binary_accuracy: 0.9878 - val_loss: 0.0568 - val_binary_accuracy: 0.9820
# Epoch 222/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0498 - binary_accuracy: 0.9872 - val_loss: 0.0546 - val_binary_accuracy: 0.9835
# Epoch 223/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0498 - binary_accuracy: 0.9876 - val_loss: 0.0555 - val_binary_accuracy: 0.9835
# Epoch 224/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0507 - binary_accuracy: 0.9875 - val_loss: 0.0559 - val_binary_accuracy: 0.9845
# Epoch 225/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0493 - binary_accuracy: 0.9879 - val_loss: 0.0541 - val_binary_accuracy: 0.9835
# Epoch 226/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0496 - binary_accuracy: 0.9880 - val_loss: 0.0552 - val_binary_accuracy: 0.9840
# Epoch 227/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0489 - binary_accuracy: 0.9879 - val_loss: 0.0542 - val_binary_accuracy: 0.9835
# Epoch 228/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0496 - binary_accuracy: 0.9876 - val_loss: 0.0541 - val_binary_accuracy: 0.9850
# Epoch 229/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0489 - binary_accuracy: 0.9880 - val_loss: 0.0555 - val_binary_accuracy: 0.9835
# Epoch 230/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0519 - binary_accuracy: 0.9871 - val_loss: 0.0571 - val_binary_accuracy: 0.9830
# Epoch 231/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0494 - binary_accuracy: 0.9877 - val_loss: 0.0555 - val_binary_accuracy: 0.9835
# Epoch 232/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0478 - binary_accuracy: 0.9873 - val_loss: 0.0560 - val_binary_accuracy: 0.9835
# Epoch 233/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0501 - binary_accuracy: 0.9870 - val_loss: 0.0557 - val_binary_accuracy: 0.9835
# Epoch 234/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0514 - binary_accuracy: 0.9863 - val_loss: 0.0539 - val_binary_accuracy: 0.9845
# Epoch 235/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0495 - binary_accuracy: 0.9872 - val_loss: 0.0549 - val_binary_accuracy: 0.9845
# Epoch 236/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0498 - binary_accuracy: 0.9871 - val_loss: 0.0568 - val_binary_accuracy: 0.9825
# Epoch 237/270
# 8000/8000 [==============================] - 0s 10us/step - loss: 0.0485 - binary_accuracy: 0.9882 - val_loss: 0.0569 - val_binary_accuracy: 0.9830
# Epoch 238/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0520 - binary_accuracy: 0.9861 - val_loss: 0.0541 - val_binary_accuracy: 0.9845
# Epoch 239/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0488 - binary_accuracy: 0.9879 - val_loss: 0.0531 - val_binary_accuracy: 0.9845
# Epoch 240/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0492 - binary_accuracy: 0.9883 - val_loss: 0.0539 - val_binary_accuracy: 0.9845
# Epoch 241/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0490 - binary_accuracy: 0.9874 - val_loss: 0.0546 - val_binary_accuracy: 0.9835
# Epoch 242/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0475 - binary_accuracy: 0.9886 - val_loss: 0.0552 - val_binary_accuracy: 0.9840
# Epoch 243/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0504 - binary_accuracy: 0.9873 - val_loss: 0.0558 - val_binary_accuracy: 0.9835
# Epoch 244/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0489 - binary_accuracy: 0.9875 - val_loss: 0.0566 - val_binary_accuracy: 0.9845
# Epoch 245/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0477 - binary_accuracy: 0.9875 - val_loss: 0.0558 - val_binary_accuracy: 0.9835
# Epoch 246/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0477 - binary_accuracy: 0.9879 - val_loss: 0.0558 - val_binary_accuracy: 0.9835
# Epoch 247/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0495 - binary_accuracy: 0.9869 - val_loss: 0.0548 - val_binary_accuracy: 0.9835
# Epoch 248/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0503 - binary_accuracy: 0.9869 - val_loss: 0.0543 - val_binary_accuracy: 0.9835
# Epoch 249/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0472 - binary_accuracy: 0.9881 - val_loss: 0.0535 - val_binary_accuracy: 0.9845
# Epoch 250/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0483 - binary_accuracy: 0.9879 - val_loss: 0.0531 - val_binary_accuracy: 0.9855
# Epoch 251/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0495 - binary_accuracy: 0.9867 - val_loss: 0.0563 - val_binary_accuracy: 0.9830
# Epoch 252/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0484 - binary_accuracy: 0.9875 - val_loss: 0.0541 - val_binary_accuracy: 0.9850
# Epoch 253/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0491 - binary_accuracy: 0.9880 - val_loss: 0.0529 - val_binary_accuracy: 0.9855
# Epoch 254/270
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.0492 - binary_accuracy: 0.9864 - val_loss: 0.0555 - val_binary_accuracy: 0.9835
# Epoch 255/270
# 8000/8000 [==============================] - 0s 8us/step - loss: 0.0480 - binary_accuracy: 0.9885 - val_loss: 0.0545 - val_binary_accuracy: 0.9845
# Epoch 256/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0463 - binary_accuracy: 0.9889 - val_loss: 0.0590 - val_binary_accuracy: 0.9830
# Epoch 257/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0486 - binary_accuracy: 0.9875 - val_loss: 0.0538 - val_binary_accuracy: 0.9850
# Epoch 258/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0482 - binary_accuracy: 0.9871 - val_loss: 0.0553 - val_binary_accuracy: 0.9830
# Epoch 259/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0474 - binary_accuracy: 0.9885 - val_loss: 0.0595 - val_binary_accuracy: 0.9830
# Epoch 260/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0484 - binary_accuracy: 0.9875 - val_loss: 0.0549 - val_binary_accuracy: 0.9850
# Epoch 261/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0505 - binary_accuracy: 0.9869 - val_loss: 0.0542 - val_binary_accuracy: 0.9835
# Epoch 262/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0467 - binary_accuracy: 0.9886 - val_loss: 0.0565 - val_binary_accuracy: 0.9830
# Epoch 263/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0465 - binary_accuracy: 0.9884 - val_loss: 0.0541 - val_binary_accuracy: 0.9860
# Epoch 264/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0494 - binary_accuracy: 0.9877 - val_loss: 0.0562 - val_binary_accuracy: 0.9830
# Epoch 265/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0493 - binary_accuracy: 0.9880 - val_loss: 0.0552 - val_binary_accuracy: 0.9850
# Epoch 266/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0470 - binary_accuracy: 0.9884 - val_loss: 0.0538 - val_binary_accuracy: 0.9845
# Epoch 267/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0481 - binary_accuracy: 0.9882 - val_loss: 0.0564 - val_binary_accuracy: 0.9840
# Epoch 268/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0478 - binary_accuracy: 0.9875 - val_loss: 0.0550 - val_binary_accuracy: 0.9840
# Epoch 269/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0468 - binary_accuracy: 0.9884 - val_loss: 0.0553 - val_binary_accuracy: 0.9845
# Epoch 270/270
# 8000/8000 [==============================] - 0s 7us/step - loss: 0.0465 - binary_accuracy: 0.9883 - val_loss: 0.0540 - val_binary_accuracy: 0.9850

# %%
ann.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 26)                702
# _________________________________________________________________
# dense_2 (Dense)              (None, 11)                297
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 11)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 72
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 14
# =================================================================
# Total params: 1,085
# Trainable params: 1,085
# Non-trainable params: 0
# _________________________________________________________________

# %%
scores = ann.evaluate(x_test_ann, y_test_ann, verbose = 0)
print("Test Accuracy (Artificial Neural Network): {}%" .format(scores[1] * 100))
# Out:
# Test Accuracy (Artificial Neural Network): 98.5%

# %%
scores
# Out:
# [0.05400460645928979, 0.985]

# %%
y_pred = ann.predict(x_test_ann)

# Compute confusion matrix
matrix = confusion_matrix(y_test_ann.argmax(axis = 1), y_pred.argmax(axis = 1)) # Building the confusion matrix

# %%
matrix
# Out:
# array([[ 968,   25],
#        [   5, 1002]])

# %% [markdown]
# ## Random Forest Classification

# %%
# Training the model
rf = RandomForestClassifier(n_estimators = 100, class_weight = 'balanced')
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=None, oob_score=False,
#                        random_state=None, verbose=0, warm_start=False)

# %%
# Model predictions
y_pred = rf.predict(x_test)
probs = rf.predict_proba(x_test)[:, 1] # Positive class probabilities

# %%
params = {'legend.fontsize': 'small',
         'axes.labelsize': 'x-small',
         'axes.titlesize':'small',
         'xtick.labelsize':'x-small',
         'ytick.labelsize':'x-small'}
pylab.rcParams.update(params)

# %%
# Confusion matrix code adapted from https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
def plot_confusion_matrix(cm, classes, normalize = False, title = 'Confusion matrix', cmap = plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize = True.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis = 1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    dummy = np.array([[0, 0], [0, 0]])
    plt.figure(figsize = (6, 6))
    plt.imshow(dummy, interpolation = 'nearest', cmap = cmap)
    plt.title(title)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment = "center",
                 color = "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()


# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
class_names = ['not mining pool', 'mining pool']
np.set_printoptions(precision = 2)

# Plot confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes = class_names, normalize = False, title = 'Bitcoin Mining Pool Detector using Random Forest - Confusion Matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 978   15]
#  [   6 1001]]

# %%
# Calculating Accuracy
acc = (cnf_matrix[0][0] + cnf_matrix[1][1]) / (cnf_matrix[0][0] + cnf_matrix[1][1] + cnf_matrix[0][1] + cnf_matrix[1][0])

# %%
print("Test Accuracy (Random Forest Classification): {}%" .format(acc * 100))
# Out:
# Test Accuracy (Random Forest Classification): 98.95%

# %%
plt.savefig('RF_CM.jpg')

# %% [markdown]
# ### What is the contribution of each feature?

# %%
params = {'legend.fontsize': 'small',
         'axes.labelsize': 'small',
         'axes.titlesize':'small',
         'xtick.labelsize':'small',
         'ytick.labelsize':'small'
         }
pylab.rcParams.update(params)

# %%
x_pos = np.arange(len(features.columns))
btc_importances = rf.feature_importances_

inds = np.argsort(btc_importances)[::-1]
btc_importances = btc_importances[inds]
cols = features.columns[inds]
bar_width = .8

# How many features to plot?
n_features = 26
x_pos = x_pos[:n_features][::-1]
btc_importances = btc_importances[:n_features]

# Plot
plt.figure(figsize = (26, 10))
plt.barh(x_pos, btc_importances, bar_width, label = 'BTC model')
plt.yticks(x_pos, cols, rotation = 0, fontsize = 14)
plt.xlabel('feature importance', fontsize = 14)
plt.title('Mining Pool Detector', fontsize = 20)
plt.tight_layout()

# %%
plt.savefig('RFfeatureImportance.jpg')

# %% [markdown]
# ### Are False Positives associated with dark mining pools?

# %%
# Data points where model predicts true, but are labelled as false
false_positives = (y_test == False) & (y_pred == True)

# %%
# Subset to test set data only
df_test = df.iloc[indices_test, :]

print('False Positive addresses')

# Subset test set to false positives only
df_test.iloc[false_positives].head(15)
# Out:
# False Positive addresses
#       is_miner                             address  output_month_min  \
# 4257     False  14jnsfMhGGch7i3CQ5jynuMeU2ZdBnqo2P        1433116800
# 4315     False  1NMZoAy1zSFBBadGvRXejppDBcK4ChqXhA        1435708800
# 9195     False  1BsMvsmuvuFgrJoY1TRhow6tCZFSd7tRnv        1375315200
# 3965     False  183aFi7jUkDchYKaA4qYZcoLTSFu6QuDGY        1417392000
# 8833     False  1JmoqNhrHXmB8Kv9S4HbEwumfFJqdmVCpM        1448928000
# 9131     False  1HUfcyEyFEexMzTtswfWPHickhbU2dC5sd        1404172800
# 9891     False  1HzNtsocGqDvSKXM3Zvvx91t5TKPmmJDwq        1367366400
# 4201     False  1FH328p5TggKdn2vwtAVDmWsSebcidjyzL        1364774400
# 8772     False  1LVHGkXLiFQdfMLQxmCm3RYK7nazpJT9mt        1383264000
# 4103     False  1HibpmNG9qGrdJLXdEWymBMrcemUmf6qzK        1420070400
# 8771     False  1MAY5kipeRvtzGN4bxyu8LGuD5WTnzrA4d        1420070400
# 4262     False  14Hs9NDMhxbAL6Q3ABLRsEUzbRLYmQehmb        1454284800
# 4073     False  12cosW7x9jW8zAFnUEbyXb8HSGXjpjk2cy        1391212800
# 4210     False  13BSp9hGnuR9euQLiTaniCPA1qS1F8W5F2        1393632000
# 9836     False  1EV96fsGrchpnz6N1csiehpvxBoVodSat3        1430438400
#
#       output_month_max  input_month_min  input_month_max  output_active_time  \
# 4257        1454284800       1433116800       1467331200            21168000
# 4315        1517443200       1435708800       1517443200            81734400
# 9195        1406851200       1375315200       1406851200            31536000
# 3965        1433116800       1417392000       1433116800            15724800
# 8833        1470009600       1448928000       1470009600            21081600
# 9131        1483228800       1404172800       1485907200            79056000
# 9891        1443657600       1367366400       1443657600            76291200
# 4201        1438387200       1367366400       1491004800            73612800
# 8772        1446336000       1383264000       1446336000            63072000
# 4103        1456790400       1420070400       1456790400            36720000
# 8771        1504224000       1420070400       1504224000            84153600
# 4262        1493596800       1493596800       1493596800            39312000
# 4073        1446336000       1391212800       1446336000            55123200
# 4210        1530403200       1398902400       1464739200           136771200
# 9836        1443657600       1430438400       1443657600            13219200
#
#       input_active_time  io_max_lag  io_min_lag  ...  input_active_months  \
# 4257           34214400   -13046400           0  ...                   10
# 4315           81734400           0           0  ...                   31
# 9195           31536000           0           0  ...                    9
# 3965           15724800           0           0  ...                    7
# 8833           21081600           0           0  ...                    7
# 9131           81734400    -2678400           0  ...                   22
# 9891           76291200           0           0  ...                   16
# 4201          123638400   -52617600    -2592000  ...                   13
# 8772           63072000           0           0  ...                    7
# 4103           36720000           0           0  ...                   14
# 8771           84153600           0           0  ...                   16
# 4262                  0           0   -39312000  ...                    1
# 4073           55123200           0           0  ...                    9
# 4210           65836800    65664000    -5270400  ...                   22
# 9836           13219200           0           0  ...                    6
#
#       total_tx_input_count total_tx_input_value  mean_tx_input_value  \
# 4257                   555           1819691000    3278722.522522523
# 4315                   201           1917172621    9538172.243781095
# 9195                    30           2456396518   81879883.933333333
# 3965                    75           5308327511   70777700.146666667
# 8833                    25           1717537662          68701506.48
# 9131                    29           9892675100  341126727.586206897
# 9891                    47            810426607    17243119.29787234
# 4201                    79          20933342646  264979020.835443038
# 8772                    23             87527594    3805547.565217391
# 4103                   376          37292392924   99181896.074468085
# 8771                    24           6263413397  260975558.208333333
# 4262                  1064          58924792627   55380444.198308271
# 4073                   185            963437214    5207768.724324324
# 4210                   122           8260419328   67708355.147540984
# 9836                    43            435639413   10131149.139534884
#
#       stddev_tx_input_value  total_input_tx mean_monthly_input_value  \
# 4257           2.891334e+06             435        3278722.522522523
# 4315           7.636877e+06             181        9538172.243781095
# 9195           1.968312e+08              30       81879883.933333333
# 3965           1.011751e+08              56       70777700.146666667
# 8833           7.300907e+07              24              68701506.48
# 9131           1.153153e+08              24      341126727.586206897
# 9891           3.138797e+07              36        17243119.29787234
# 4201           1.996370e+08              28      264979020.835443038
# 8772           5.384164e+06              17        3805547.565217391
# 4103           1.005990e+08             357       99181896.074468085
# 8771           4.174941e+08              23      260975558.208333333
# 4262           1.372931e+08               6       55380444.198308271
# 4073           1.637681e+07              14        5207768.724324324
# 4210           6.086495e+07             115       67708355.147540984
# 9836           3.741935e+07              25       10131149.139534884
#
#       mean_monthly_input_count  mean_output_idle_time  mean_input_idle_time
# 4257                       1.0           1.145023e+05          2.090139e+05
# 4315                       1.0           4.155540e+05          5.452666e+05
# 9195                       1.0           1.155213e+06          1.115463e+06
# 3965                       1.0           2.173753e+05          2.952240e+05
# 8833                       1.0           8.087578e+05          8.439167e+05
# 9131                       1.0           2.849381e+06          3.542165e+06
# 9891                       1.0           1.754634e+06          2.205672e+06
# 4201                       1.0           9.524109e+05          4.545531e+06
# 8772                       1.0           3.455979e+06          4.147162e+06
# 4103                       1.0           9.758381e+04          1.023681e+05
# 8771                       1.0           3.752129e+06          3.754047e+06
# 4262                       1.0           5.996551e+05          2.109500e+03
# 4073                       1.0           2.949524e+05          4.201130e+06
# 4210                       1.0           8.962849e+05          5.965102e+05
# 9836                       1.0           3.556342e+05          6.221781e+05
#
# [15 rows x 28 columns]

# %% [markdown]
# # Comparison between ANN and RF

# %%
index = inds[: -1]
index
# Out:
# array([13,  9,  0, 17,  8, 10, 18,  2,  4,  5, 16, 11,  1, 14, 19, 22,  7,
#         3, 24, 21, 12, 25, 20,  6, 15])

# %%
data_top = x_train.columns

# %%
xann = pd.DataFrame(data = x_train_ann[0:, 0:], index = [i for i in range(x_train_ann.shape[0])], columns = [str(i) for i in data_top])
xtann = pd.DataFrame(data = x_test_ann[0:, 0:], index = [i for i in range(x_test_ann.shape[0])], columns = [str(i) for i in data_top])
xrf = x_train
xtrf = x_test
i = 1

# %%
ann_acc = [scores[1] * 100]
rf_acc = [acc * 100]
print("{}- All 26 features taken as input:" .format(i))
print("ANN test accuracy = {}%, RF test accuracy = {}%" .format(ann_acc[0], rf_acc[0]))
for x in reversed(index):
    xann = xann.drop(columns = [data_top[x]])	
    xtann = xtann.drop(columns = [data_top[x]])
    xrf = xrf.drop(columns = [data_top[x]])
    xtrf = xtrf.drop(columns = [data_top[x]])
    
    # Creating model
    ann = Sequential()
    ann.add(Dense(26, activation = 'tanh', kernel_initializer = 'glorot_uniform'))
    ann.add(Dense(11, activation = 'tanh'))
    ann.add(Dropout(0.5))
    ann.add(Dense(6, activation = 'tanh'))
    ann.add(Dense(num_classes, activation = 'softmax'))

    rmsprop = optimizers.RMSprop(learn_rate)
    ann.compile(loss = 'binary_crossentropy', optimizer = rmsprop, metrics = ['binary_accuracy']) # Compiling the model

    # Model fitting
    ann.fit(np.array(xann), y_train_ann, batch_size = batch_size, verbose = 0, epochs = epochs)
    scores_ann = ann.evaluate(xtann, y_test_ann, verbose = 0)

    # Training the model
    rf = RandomForestClassifier(n_estimators = 100, class_weight = 'balanced')
    rf.fit(xrf, y_train)

    # Model predictions
    y_pred = rf.predict(xtrf)
    cnf_matrix = confusion_matrix(y_test, y_pred)
    acc = (cnf_matrix[0][0] + cnf_matrix[1][1]) / (cnf_matrix[0][0] + cnf_matrix[1][1] + cnf_matrix[0][1] + cnf_matrix[1][0])
    i += 1
    print("{}- Dropping {}:" .format(i, data_top[x]))
    print("ANN test accuracy = {}%, RF test accuracy = {}%" .format(scores_ann[1] * 100, acc * 100))
    ann_acc.append(scores_ann[1] * 100)
    rf_acc.append(acc * 100)
# Out:
# 1- All 26 features taken as input:
# ANN test accuracy = 98.5%, RF test accuracy = 98.95%
# 2- Dropping mean_monthly_output_count:
# ANN test accuracy = 98.45%, RF test accuracy = 98.9%
# 3- Dropping io_max_lag:
# ANN test accuracy = 98.45%, RF test accuracy = 98.95%
# 4- Dropping stddev_tx_input_value:
# ANN test accuracy = 98.4%, RF test accuracy = 98.95%
# 5- Dropping mean_input_idle_time:
# ANN test accuracy = 98.25%, RF test accuracy = 98.85000000000001%
# 6- Dropping stddev_tx_output_value:
# ANN test accuracy = 98.65%, RF test accuracy = 98.85000000000001%
# 7- Dropping total_input_tx:
# ANN test accuracy = 98.2%, RF test accuracy = 98.9%
# 8- Dropping mean_output_idle_time:
# ANN test accuracy = 98.2%, RF test accuracy = 98.7%
# 9- Dropping input_month_max:
# ANN test accuracy = 98.45%, RF test accuracy = 98.8%
# 10- Dropping io_min_lag:
# ANN test accuracy = 98.15%, RF test accuracy = 98.75%
# 11- Dropping mean_monthly_input_value:
# ANN test accuracy = 98.05%, RF test accuracy = 98.65%
# 12- Dropping mean_tx_input_value:
# ANN test accuracy = 98.3%, RF test accuracy = 98.85000000000001%
# 13- Dropping mean_monthly_output_value:
# ANN test accuracy = 98.0%, RF test accuracy = 98.7%
# 14- Dropping output_month_max:
# ANN test accuracy = 98.2%, RF test accuracy = 98.85000000000001%
# 15- Dropping mean_tx_output_value:
# ANN test accuracy = 98.2%, RF test accuracy = 98.6%
# 16- Dropping input_active_months:
# ANN test accuracy = 98.15%, RF test accuracy = 98.65%
# 17- Dropping input_active_time:
# ANN test accuracy = 98.35000000000001%, RF test accuracy = 98.6%
# 18- Dropping output_active_time:
# ANN test accuracy = 98.1%, RF test accuracy = 98.65%
# 19- Dropping input_month_min:
# ANN test accuracy = 98.4%, RF test accuracy = 98.75%
# 20- Dropping total_tx_input_value:
# ANN test accuracy = 98.3%, RF test accuracy = 98.7%
# 21- Dropping total_tx_output_value:
# ANN test accuracy = 97.95%, RF test accuracy = 97.85000000000001%
# 22- Dropping output_active_months:
# ANN test accuracy = 98.15%, RF test accuracy = 97.55%
# 23- Dropping total_tx_input_count:
# ANN test accuracy = 98.1%, RF test accuracy = 97.6%
# 24- Dropping output_month_min:
# ANN test accuracy = 94.69999999999999%, RF test accuracy = 94.5%
# 25- Dropping total_tx_output_count:
# ANN test accuracy = 94.45%, RF test accuracy = 94.45%
# 26- Dropping total_output_tx:
# ANN test accuracy = 49.65%, RF test accuracy = 50.349999999999994%

# %%
# Create plots with pre-defined labels
f = plt.figure(figsize = (10, 10))
ax = f.add_subplot(121)
t = list(np.arange(1., 27., 1))
t.reverse()
ax.plot(t, rf_acc, 'r-', label = 'Random Forest')
ax.plot(t, ann_acc, 'b--', label = 'Artificial Neural Network')

legend = ax.legend(loc = 'lower right', shadow = True, fontsize = 'x-small')

# Put a nicer background color on the legend.
legend.get_frame().set_facecolor('C6')
plt.ylabel('Test Accuracy (%)')
plt.xlabel('Number of features')
plt.title('RF vs ANN (Accuracy Comparison)')
plt.show()

# %%
plt.savefig('RFvsANN.jpg')

# %% [markdown]
# # Trying other approaches

# %% [markdown]
# ## Naive Bayes

# %%
# Fitting Naive Bayes to the Training set
nb = GaussianNB()
nb.fit(x_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
# Predicting the Test set results
y_pred = nb.predict(x_test)

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
class_names = ['not mining pool', 'mining pool']
np.set_printoptions(precision = 3)

# Plot confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes = class_names, normalize = False, title = 'Bitcoin Mining Pool Detector using Naive Bayes - Confusion Matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[871 122]
#  [ 51 956]]

# %%
# Calculating Accuracy
acc = (cnf_matrix[0][0] + cnf_matrix[1][1]) / (cnf_matrix[0][0] + cnf_matrix[1][1] + cnf_matrix[0][1] + cnf_matrix[1][0])
print("Test Accuracy (Naive Bayes Classification): {}%" .format(acc * 100))
# Out:
# Test Accuracy (Naive Bayes Classification): 91.35%

# %%
plt.savefig('NaiveBayesCM.jpg')
